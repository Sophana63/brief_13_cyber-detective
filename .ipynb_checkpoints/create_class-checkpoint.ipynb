# %%
from bs4 import BeautifulSoup
import requests
import lxml
import pandas as pd

# %%
# création de l'une classe pouvant scraper un site web
# il faudra mettre en paramètre le lien du site à scraper
class Scraping:
    def __init__(self, link):
        self.link = link


    def myrequest (self):
        def export_table_and_print(data):
            table = pd.DataFrame(data, columns=[
                                 'Name', 'Price', 'Rating', 'Instock', 'Link'])
            table.index = table.index + 1 
        
        def get_book_attributes(book):
            name = book.find('h3').find('a').attrs['title']
            price = book.find('p', class_='price_color').text
            price = price.replace('Â£', "")
            rating = book.find('p', class_='star-rating')
            dispo = book.find('p', class_='instock availability').text
            dispo = dispo.replace("\n\n    \n        ", "")
            dispo = dispo.replace("\n    \n", "")
            link = book.find('h3').find('a').attrs['href']
            l = rating['class']
            s = " ".join(l)
            s = s.replace("star-rating ", "")
            # remplace le texte en chiffre
            if s == "One":
                rating_number = 1
            elif s =="Two":
                rating_number = 2
            elif s =="Three":
                rating_number = 3
            elif s =="Four":
                rating_number = 4
            elif s =="Five":
                rating_number = 5
            data['Name'].append(name)
            data['Price'].append(price)
            data['Rating'].append(rating_number)
            data['Instock'].append(dispo)
            data['Link'].append(link)
            return data
    
        data = {
            'Name' : [], 'Price' : [], 'Rating' : [], 'Instock' : [], 'Link' : []
        }
        
        page = requests.get(self.link)
        if page.status_code == requests.codes.ok:
            bs = BeautifulSoup(page.text, 'lxml')
            # récupération de tous les objets
            list_all_book = bs.findAll('article', class_='product_pod')        

            for book in list_all_book:
                get_book_attributes(book)
        
        return data

# %%
# appelle de ma classe Scraping
lien = 'https://books.toscrape.com/catalogue/page-38.html'

scrap = Scraping(lien)
df = pd.DataFrame(scrap.myrequest()).reset_index()
df
# Out:
#     index                                               Name  Price  Rating  \
# 0       0  The Lean Startup: How Today's Entrepreneurs Us...  33.92       3
# 1       1                   The Last Painting of Sara de Vos  55.55       2
# 2       2                        The Land of 10,000 Madonnas  29.64       4
# 3       3                                     The Infinities  27.41       1
# 4       4                               The Husband's Secret  52.51       5
# 5       5  The Hitchhiker's Guide to the Galaxy (Hitchhik...  47.80       3
# 6       6                                 The Guns of August  14.54       2
# 7       7  The Guernsey Literary and Potato Peel Pie Society  49.53       1
# 8       8                                      The Goldfinch  43.58       3
# 9       9                   The Giver (The Giver Quartet #1)  12.30       1
# 10     10                        The Girl with All the Gifts  49.47       3
# 11     11  The Girl Who Played with Fire (Millennium Tril...  22.14       2
# 12     12  The Girl Who Kicked the Hornet's Nest (Millenn...  57.48       1
# 13     13                                         The Exiled  43.45       3
# 14     14  The End of Faith: Religion, Terror, and the Fu...  22.13       4
# 15     15  The Elegant Universe: Superstrings, Hidden Dim...  13.03       4
# 16     16  The Disappearing Spoon: And Other True Tales o...  57.35       5
# 17     17   The Devil Wears Prada (The Devil Wears Prada #1)  44.29       1
# 18     18  The Demon-Haunted World: Science as a Candle i...  52.25       4
# 19     19            The Day the Crayons Came Home (Crayons)  26.33       5
#
#      Instock                                               Link
# 0   In stock  the-lean-startup-how-todays-entrepreneurs-use-...
# 1   In stock    the-last-painting-of-sara-de-vos_259/index.html
# 2   In stock          the-land-of-10000-madonnas_258/index.html
# 3   In stock                      the-infinities_257/index.html
# 4   In stock                 the-husbands-secret_256/index.html
# 5   In stock  the-hitchhikers-guide-to-the-galaxy-hitchhiker...
# 6   In stock                  the-guns-of-august_254/index.html
# 7   In stock  the-guernsey-literary-and-potato-peel-pie-soci...
# 8   In stock                       the-goldfinch_252/index.html
# 9   In stock       the-giver-the-giver-quartet-1_251/index.html
# 10  In stock         the-girl-with-all-the-gifts_250/index.html
# 11  In stock  the-girl-who-played-with-fire-millennium-trilo...
# 12  In stock  the-girl-who-kicked-the-hornets-nest-millenniu...
# 13  In stock                          the-exiled_247/index.html
# 14  In stock  the-end-of-faith-religion-terror-and-the-futur...
# 15  In stock  the-elegant-universe-superstrings-hidden-dimen...
# 16  In stock  the-disappearing-spoon-and-other-true-tales-of...
# 17  In stock  the-devil-wears-prada-the-devil-wears-prada-1_...
# 18  In stock  the-demon-haunted-world-science-as-a-candle-in...
# 19  In stock  the-day-the-crayons-came-home-crayons_241/inde...
