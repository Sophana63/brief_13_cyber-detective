# %%
import pandas as pd
import re

from wordcloud import WordCloud
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt

# %%
def filtre(text):

    text = text.lower()
    text = text.replace('\n', ' ').replace('\r', '').replace('http', '')
    text = ' '.join(text.split())
    text = re.sub(r"[A-Za-z\.]*[0-9]+[A-Za-z%°\.]*", "", text)
    text = re.sub(r"(\s\-\s|-$)", "", text)
    text = re.sub(r"[,\!\?\%\(\)\/\"]", "", text)
    text = re.sub(r"\&\S*\s", "", text)
    text = re.sub(r"\&", "", text)
    text = re.sub(r"\+", "", text)
    text = re.sub(r"\#", "", text)
    text = re.sub(r"\$", "", text)
    text = re.sub(r"\£", "", text)
    text = re.sub(r"\%", "", text)
    text = re.sub(r"\:", "", text)
    text = re.sub(r"\@", "", text)
    text = re.sub(r"\-", "", text)
    text = re.sub(r"\;", "", text)

    return text

# %%
df = pd.read_csv('csv/the_art_of_war.csv', delimiter='|', on_bad_lines='skip')
df.columns = ['tweet']

text = " ".join(i for i in df['tweet'].str.replace('https', ''))
clean_text = filtre(text)
clean_text
exclure_mots = ['t', 'co', 'd', 'du', 'de', 'la', 'des', 'le', 'et', 'est', 'elle', 'une', 'en', 'que', 'aux', 'qui', 'ces', 'les', 'dans', 'sur', 'l', 'un', 'pour', 'par', 'il', 'ou', 'à', 'ce', 'a', 'sont', 'cas', 'plus', 'leur', 'se', 's', 'vous', 'au', 'c', 'aussi', 'toutes', 'autre', 'comme'] + list(STOPWORDS)

# affichage avec matplotlib
wordcloud = WordCloud(collocations = False, background_color = 'white', stopwords = exclure_mots, max_words = 100).generate(text)
plt.imshow(wordcloud)
plt.axis("off")
plt.show();

# %%
df2 = pd.read_csv('csv/the_book_thief.csv', delimiter='|', on_bad_lines='skip')
df2.columns = ['tweet']

text = " ".join(i for i in df2['tweet'].str.replace('https', ''))
clean_text = filtre(text)
clean_text
exclure_mots = ['t', 'co', 'd', 'du', 'de', 'la', 'des', 'le', 'et', 'est', 'elle', 'une', 'en', 'que', 'aux', 'qui', 'ces', 'les', 'dans', 'sur', 'l', 'un', 'pour', 'par', 'il', 'ou', 'à', 'ce', 'a', 'sont', 'cas', 'plus', 'leur', 'se', 's', 'vous', 'au', 'c', 'aussi', 'toutes', 'autre', 'comme'] + list(STOPWORDS)

# affichage avec matplotlib
wordcloud = WordCloud(collocations = False, background_color = 'white', stopwords = exclure_mots, max_words = 100).generate(text)
plt.imshow(wordcloud)
plt.axis("off")
plt.show();

# %%
df3 = pd.read_csv('csv/the_picture_of_dorian_grey.csv', delimiter='|', on_bad_lines='skip')
df3.columns = ['tweet']

text = " ".join(i for i in df3['tweet'].str.replace('https', ''))
clean_text = filtre(text)
clean_text
exclure_mots = ['t', 'co', 'd', 'du', 'de', 'la', 'des', 'le', 'et', 'est', 'elle', 'une', 'en', 'que', 'aux', 'qui', 'ces', 'les', 'dans', 'sur', 'l', 'un', 'pour', 'par', 'il', 'ou', 'à', 'ce', 'a', 'sont', 'cas', 'plus', 'leur', 'se', 's', 'vous', 'au', 'c', 'aussi', 'toutes', 'autre', 'comme'] + list(STOPWORDS)

# affichage avec matplotlib
wordcloud = WordCloud(collocations = False, background_color = 'white', stopwords = exclure_mots, max_words = 100).generate(text)
plt.imshow(wordcloud)
plt.axis("off")
plt.show();

# %%
df4 = pd.read_csv('csv/the_song_of_achilles.csv', delimiter='|', on_bad_lines='skip')
df4.columns = ['tweet']

text = " ".join(i for i in df4['tweet'].str.replace('https', ''))
clean_text = filtre(text)
clean_text
exclure_mots = ['t', 'co', 'd', 'du', 'de', 'la', 'des', 'le', 'et', 'est', 'elle', 'une', 'en', 'que', 'aux', 'qui', 'ces', 'les', 'dans', 'sur', 'l', 'un', 'pour', 'par', 'il', 'ou', 'à', 'ce', 'a', 'sont', 'cas', 'plus', 'leur', 'se', 's', 'vous', 'au', 'c', 'aussi', 'toutes', 'autre', 'comme'] + list(STOPWORDS)

# affichage avec matplotlib
wordcloud = WordCloud(collocations = False, background_color = 'white', stopwords = exclure_mots, max_words = 100).generate(text)
plt.imshow(wordcloud)
plt.axis("off")
plt.show();

# %%
df5 = pd.read_csv('csv/batman.csv', delimiter='|', on_bad_lines='skip')

text = " ".join(i for i in df5['renderedContent'].str.replace('https', ''))
clean_text = filtre(text)
clean_text
exclure_mots = ['t', 'co', 'd', 'du', 'de', 'la', 'des', 'le', 'et', 'est', 'elle', 'une', 'en', 'que', 'aux', 'qui', 'ces', 'les', 'dans', 'sur', 'l', 'un', 'pour', 'par', 'il', 'ou', 'à', 'ce', 'a', 'sont', 'cas', 'plus', 'leur', 'se', 's', 'vous', 'au', 'c', 'aussi', 'toutes', 'autre', 'comme'] + list(STOPWORDS)

# affichage avec matplotlib
wordcloud = WordCloud(collocations = False, background_color = 'white', stopwords = exclure_mots, max_words = 100).generate(text)
plt.imshow(wordcloud)
plt.axis("off")
plt.show();
# Out:
#                       id                                                url  \
# 0    1606817197149626372  https://twitter.com/craigcutch/status/16068171...
# 1    1600633888400965635  https://twitter.com/AHiggins1985/status/160063...
# 2    1600057935543304192  https://twitter.com/SHisislipper/status/160005...
# 3    1597584980892418049  https://twitter.com/wolfpacks117/status/159758...
# 4    1593090305200623616  https://twitter.com/NooneBladesmith/status/159...
# ..                   ...                                                ...
# 995   260601191157870592  https://twitter.com/adambakercolleg/status/260...
# 996   258337559116144641  https://twitter.com/GodDickStarman/status/2583...
# 997   242808279837835264  https://twitter.com/RellyRellRella/status/2428...
# 998   240325301387808768  https://twitter.com/oldmesamememe/status/24032...
# 999   238038832044449795  https://twitter.com/WoutdeNatris/status/238038...
#
#                           date  \
# 0    2022-12-25 01:00:47+00:00
# 1    2022-12-07 23:30:31+00:00
# 2    2022-12-06 09:21:54+00:00
# 3    2022-11-29 13:35:15+00:00
# 4    2022-11-17 03:55:01+00:00
# ..                         ...
# 995  2012-10-23 04:39:00+00:00
# 996  2012-10-16 22:44:08+00:00
# 997  2012-09-04 02:16:19+00:00
# 998  2012-08-28 05:49:51+00:00
# 999  2012-08-21 22:24:14+00:00
#
#                                        renderedContent  \
# 0    @AidanJohnMoffat In the Dark Knight Returns bo...
# 1    @jaimonjahn @CultureCrave @Variety At least bu...
# 2    @evleynn cobra kai \nKarate kid trilogy \nReco...
# 3    @Vicsage1984 Well, to be fair, neither batman ...
# 4    🤔Say what you want about Frank Millar's storyl...
# ..                                                 ...
# 995  Well @AdrianneCurry , the Dark Night Returns P...
# 996  Batman: Year One was just like the book. I wis...
# 997  The Thing abt Batman Returns its like a Comic ...
# 998  Late night reading.. Batman: The Dark Knight R...
# 999  The dark night rises. Night out with son befor...
#
#                                           hashtags  replyCount  retweetCount  \
# 0                                              NaN           0             0
# 1                                              NaN           2             0
# 2                                              NaN           1             0
# 3                                              NaN           1             0
# 4                                              NaN           0             0
# ..                                             ...         ...           ...
# 995                                            NaN           0             0
# 996                                            NaN           0             0
# 997                                            NaN           0             0
# 998  'batman', 'darkknight', 'book', 'frankmiller'           0             0
# 999                                       'Batman'           0             0
#
#      likeCount
# 0            0
# 1            0
# 2            1
# 3            1
# 4            0
# ..         ...
# 995          0
# 996          0
# 997          0
# 998          0
# 999          0
#
# [1000 rows x 8 columns]
