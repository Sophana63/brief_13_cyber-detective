# %%
#!pip install selenium

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import requests
import lxml
import pandas as pd

# %%
# création de l'une classe pouvant scraper un site web
# il faudra mettre en paramètre le lien du site à scraper
class Scraping:
    def __init__(self, link):
        self.link = link


    def myrequest (self):
        def export_table_and_print(data):
            table = pd.DataFrame(data, columns=[
                                 'Name', 'Price', 'Rating', 'Instock', 'Link'])
            table.index = table.index + 1 
        
        def get_book_attributes(book):     
            name = book.find('h3').find('a').attrs['title']
            price = book.find('p', class_='price_color').text
            price = price.replace('Â£', "")
            rating = book.find('p', class_='star-rating')
            dispo = book.find('p', class_='instock availability').text
            dispo = dispo.replace("\n\n    \n        ", "")
            dispo = dispo.replace("\n    \n", "")
            link = book.find('h3').find('a').attrs['href']
            l = rating['class']
            s = " ".join(l)
            s = s.replace("star-rating ", "")
            # remplace le texte en chiffre
            if s == "One":
                rating_number = 1
            elif s =="Two":
                rating_number = 2
            elif s =="Three":
                rating_number = 3
            elif s =="Four":
                rating_number = 4
            elif s =="Five":
                rating_number = 5
            data['Name'].append(name)
            data['Price'].append(price)
            data['Rating'].append(rating_number)
            data['Instock'].append(dispo)
            data['Link'].append(link)
            return data
    
        data = {
            'Name' : [], 'Price' : [], 'Rating' : [], 'Instock' : [], 'Link' : []
        }
        
        page = requests.get(self.link)
        if page.status_code == requests.codes.ok:
            bs = BeautifulSoup(page.text, 'lxml')
            # récupération de tous les objets
            list_all_book = bs.findAll('article', class_='product_pod')        

            for book in list_all_book:
                get_book_attributes(book)
        
        return data

# %%
import time
from selenium.webdriver.common.by import By

# lien du site à scraper
lien = 'https://books.toscrape.com'


# ouvreture de Chrome et affiche la page demandée dans driver.get
driver = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver")
driver.get("https://books.toscrape.com/")

pagination = True

# je boucle jusqu'à que le bouton Next n'existe plus
while pagination == True:
    # appelle de ma classe Scraping
    scrap = Scraping(lien)
    df = pd.DataFrame(scrap.myrequest()).reset_index()  
    print(df)
    try:  
        # récupération du nouveau lien 
        lien = driver.find_element(By.CLASS_NAME, 'next').find_element(By.CSS_SELECTOR, 'a').get_attribute("href")
        more_buttons = driver.find_element(By.CLASS_NAME, 'next').find_element(By.CSS_SELECTOR, 'a')
        driver.get(more_buttons.get_attribute('href'))        
    except:        
        pagination = False
        print("Plus de page")
# Out:
# C:\Users\Administrateur\AppData\Local\Temp\ipykernel_14720\3218106133.py:9: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver")
#     index                                               Name  Price  Rating  \
# 0       0                               A Light in the Attic  51.77       3
# 1       1                                 Tipping the Velvet  53.74       1
# 2       2                                         Soumission  50.10       1
# 3       3                                      Sharp Objects  47.82       4
# 4       4              Sapiens: A Brief History of Humankind  54.23       5
# 5       5                                    The Requiem Red  22.65       1
# 6       6  The Dirty Little Secrets of Getting Your Dream...  33.34       4
# 7       7  The Coming Woman: A Novel Based on the Life of...  17.93       3
# 8       8  The Boys in the Boat: Nine Americans and Their...  22.60       4
# 9       9                                    The Black Maria  52.15       1
# 10     10     Starving Hearts (Triangular Trade Trilogy, #1)  13.99       2
# 11     11                              Shakespeare's Sonnets  20.66       4
# 12     12                                        Set Me Free  17.46       5
# 13     13  Scott Pilgrim's Precious Little Life (Scott Pi...  52.29       5
# 14     14                          Rip it Up and Start Again  35.02       5
# 15     15  Our Band Could Be Your Life: Scenes from the A...  57.25       3
# 16     16                                               Olio  23.88       1
# 17     17  Mesaerion: The Best Science Fiction Stories 18...  37.59       1
# 18     18                       Libertarianism for Beginners  51.33       2
# 19     19                            It's Only the Himalayas  45.17       2
#
#      Instock                                               Link
# 0   In stock     catalogue/a-light-in-the-attic_1000/index.html
# 1   In stock        catalogue/tipping-the-velvet_999/index.html
# 2   In stock                catalogue/soumission_998/index.html
# 3   In stock             catalogue/sharp-objects_997/index.html
# 4   In stock  catalogue/sapiens-a-brief-history-of-humankind...
# 5   In stock           catalogue/the-requiem-red_995/index.html
# 6   In stock  catalogue/the-dirty-little-secrets-of-getting-...
# 7   In stock  catalogue/the-coming-woman-a-novel-based-on-th...
# 8   In stock  catalogue/the-boys-in-the-boat-nine-americans-...
# 9   In stock           catalogue/the-black-maria_991/index.html
# 10  In stock  catalogue/starving-hearts-triangular-trade-tri...
# 11  In stock      catalogue/shakespeares-sonnets_989/index.html
# 12  In stock               catalogue/set-me-free_988/index.html
# 13  In stock  catalogue/scott-pilgrims-precious-little-life-...
# 14  In stock  catalogue/rip-it-up-and-start-again_986/index....
# 15  In stock  catalogue/our-band-could-be-your-life-scenes-f...
# 16  In stock                      catalogue/olio_984/index.html
# 17  In stock  catalogue/mesaerion-the-best-science-fiction-s...
# 18  In stock  catalogue/libertarianism-for-beginners_982/ind...
# 19  In stock    catalogue/its-only-the-himalayas_981/index.html
#     index                                               Name  Price  Rating  \
# 0       0                                        In Her Wake  12.84       1
# 1       1                                    How Music Works  37.32       2
# 2       2  Foolproof Preserving: A Guide to Small Batch J...  30.52       3
# 3       3                         Chase Me (Paris Nights #2)  25.27       5
# 4       4                                         Black Dust  34.53       5
# 5       5                      Birdsong: A Story in Pictures  54.64       3
# 6       6  America's Cradle of Quarterbacks: Western Penn...  22.50       3
# 7       7                     Aladdin and His Wonderful Lamp  53.13       3
# 8       8  Worlds Elsewhere: Journeys Around Shakespeareâ...  40.30       5
# 9       9                                     Wall and Piece  44.18       4
# 10     10  The Four Agreements: A Practical Guide to Pers...  17.66       5
# 11     11  The Five Love Languages: How to Express Heartf...  31.05       3
# 12     12                                  The Elephant Tree  23.82       5
# 13     13                             The Bear and the Piano  36.89       1
# 14     14                                     Sophie's World  15.94       5
# 15     15                                        Penny Maybe  33.29       3
# 16     16     Maude (1883-1993):She Grew Up with the country  18.02       2
# 17     17                               In a Dark, Dark Wood  19.63       1
# 18     18                                Behind Closed Doors  52.22       4
# 19     19                     You can't bury them all: Poems  33.63       2
#
#      Instock                                               Link
# 0   In stock                         in-her-wake_980/index.html
# 1   In stock                     how-music-works_979/index.html
# 2   In stock  foolproof-preserving-a-guide-to-small-batch-ja...
# 3   In stock             chase-me-paris-nights-2_977/index.html
# 4   In stock                          black-dust_976/index.html
# 5   In stock        birdsong-a-story-in-pictures_975/index.html
# 6   In stock  americas-cradle-of-quarterbacks-western-pennsy...
# 7   In stock      aladdin-and-his-wonderful-lamp_973/index.html
# 8   In stock  worlds-elsewhere-journeys-around-shakespeares-...
# 9   In stock                      wall-and-piece_971/index.html
# 10  In stock  the-four-agreements-a-practical-guide-to-perso...
# 11  In stock  the-five-love-languages-how-to-express-heartfe...
# 12  In stock                   the-elephant-tree_968/index.html
# 13  In stock              the-bear-and-the-piano_967/index.html
# 14  In stock                       sophies-world_966/index.html
# 15  In stock                         penny-maybe_965/index.html
# 16  In stock  maude-1883-1993she-grew-up-with-the-country_96...
# 17  In stock                 in-a-dark-dark-wood_963/index.html
# 18  In stock                 behind-closed-doors_962/index.html
# 19  In stock        you-cant-bury-them-all-poems_961/index.html
#     index                                               Name  Price  Rating  \
# 0       0                     Slow States of Collapse: Poems  57.31       3
# 1       1                              Reasons to Stay Alive  26.41       2
# 2       2                        Private Paris (Private #10)  47.61       5
# 3       3  #HigherSelfie: Wake Up Your Life. Free Your So...  23.11       5
# 4       4                    Without Borders (Wanderlove #1)  45.07       2
# 5       5                                   When We Collided  31.77       1
# 6       6                       We Love You, Charlie Freeman  50.27       5
# 7       7            Untitled Collection: Sabbath Poems 2014  14.27       4
# 8       8  Unseen City: The Majesty of Pigeons, the Discr...  44.18       4
# 9       9                                     Unicorn Tracks  18.78       3
# 10     10  Unbound: How Eight Technologies Made Us Human,...  25.52       1
# 11     11  Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRo...  16.28       1
# 12     12  Throwing Rocks at the Google Bus: How Growth B...  31.12       3
# 13     13                                    This One Summer  19.49       4
# 14     14                                             Thirst  17.27       5
# 15     15        The Torch Is Passed: A Harding Family Story  19.09       1
# 16     16                    The Secret of Dreadwillow Carse  56.13       1
# 17     17  The Pioneer Woman Cooks: Dinnertime: Comfort C...  56.41       1
# 18     18                                The Past Never Ends  56.50       4
# 19     19  The Natural History of Us (The Fine Art of Pre...  45.22       3
#
#      Instock                                               Link
# 0   In stock       slow-states-of-collapse-poems_960/index.html
# 1   In stock               reasons-to-stay-alive_959/index.html
# 2   In stock            private-paris-private-10_958/index.html
# 3   In stock  higherselfie-wake-up-your-life-free-your-soul-...
# 4   In stock        without-borders-wanderlove-1_956/index.html
# 5   In stock                    when-we-collided_955/index.html
# 6   In stock         we-love-you-charlie-freeman_954/index.html
# 7   In stock  untitled-collection-sabbath-poems-2014_953/ind...
# 8   In stock  unseen-city-the-majesty-of-pigeons-the-discree...
# 9   In stock                      unicorn-tracks_951/index.html
# 10  In stock  unbound-how-eight-technologies-made-us-human-t...
# 11  In stock  tsubasa-world-chronicle-2-tsubasa-world-chroni...
# 12  In stock  throwing-rocks-at-the-google-bus-how-growth-be...
# 13  In stock                     this-one-summer_947/index.html
# 14  In stock                              thirst_946/index.html
# 15  In stock  the-torch-is-passed-a-harding-family-story_945...
# 16  In stock     the-secret-of-dreadwillow-carse_944/index.html
# 17  In stock  the-pioneer-woman-cooks-dinnertime-comfort-cla...
# 18  In stock                 the-past-never-ends_942/index.html
# 19  In stock  the-natural-history-of-us-the-fine-art-of-pret...
#     index                                               Name  Price  Rating  \
# 0       0           The Nameless City (The Nameless City #1)  38.16       4
# 1       1  The Murder That Never Was (Forensic Instincts #5)  54.11       3
# 2       2  The Most Perfect Thing: Inside (and Outside) a...  42.96       4
# 3       3  The Mindfulness and Acceptance Workbook for An...  23.89       4
# 4       4  The Life-Changing Magic of Tidying Up: The Jap...  16.77       3
# 5       5  The Inefficiency Assassin: Time Management Tac...  20.59       5
# 6       6  The Gutsy Girl: Escapades for Your Life of Epi...  37.13       1
# 7       7  The Electric Pencil: Drawings from Inside Stat...  56.06       1
# 8       8       The Death of Humanity: and the Case for Life  58.11       4
# 9       9  The Bulletproof Diet: Lose up to a Pound a Day...  49.05       3
# 10     10                                     The Art Forger  40.76       3
# 11     11  The Age of Genius: The Seventeenth Century and...  19.73       1
# 12     12  The Activist's Tao Te Ching: Ancient Advice fo...  32.24       5
# 13     13  Spark Joy: An Illustrated Master Class on the ...  41.83       4
# 14     14                                        Soul Reader  39.58       2
# 15     15                                           Security  39.25       2
# 16     16      Saga, Volume 6 (Saga (Collected Editions) #6)  25.02       3
# 17     17      Saga, Volume 5 (Saga (Collected Editions) #5)  51.04       2
# 18     18  Reskilling America: Learning to Labor in the T...  19.83       2
# 19     19  Rat Queens, Vol. 3: Demons (Rat Queens (Collec...  50.40       3
#
#      Instock                                               Link
# 0   In stock  the-nameless-city-the-nameless-city-1_940/inde...
# 1   In stock  the-murder-that-never-was-forensic-instincts-5...
# 2   In stock  the-most-perfect-thing-inside-and-outside-a-bi...
# 3   In stock  the-mindfulness-and-acceptance-workbook-for-an...
# 4   In stock  the-life-changing-magic-of-tidying-up-the-japa...
# 5   In stock  the-inefficiency-assassin-time-management-tact...
# 6   In stock  the-gutsy-girl-escapades-for-your-life-of-epic...
# 7   In stock  the-electric-pencil-drawings-from-inside-state...
# 8   In stock  the-death-of-humanity-and-the-case-for-life_93...
# 9   In stock  the-bulletproof-diet-lose-up-to-a-pound-a-day-...
# 10  In stock                      the-art-forger_930/index.html
# 11  In stock  the-age-of-genius-the-seventeenth-century-and-...
# 12  In stock  the-activists-tao-te-ching-ancient-advice-for-...
# 13  In stock  spark-joy-an-illustrated-master-class-on-the-a...
# 14  In stock                         soul-reader_926/index.html
# 15  In stock                            security_925/index.html
# 16  In stock  saga-volume-6-saga-collected-editions-6_924/in...
# 17  In stock  saga-volume-5-saga-collected-editions-5_923/in...
# 18  In stock  reskilling-america-learning-to-labor-in-the-tw...
# 19  In stock  rat-queens-vol-3-demons-rat-queens-collected-e...
#     index                                               Name  Price  Rating  \
# 0       0  Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Pr...  13.61       5
# 1       1   Princess Between Worlds (Wide-Awake Princess #5)  13.34       5
# 2       2                        Pop Gun War, Volume 1: Gift  18.97       1
# 3       3  Political Suicide: Missteps, Peccadilloes, Bad...  36.28       2
# 4       4                                           Patience  10.16       3
# 5       5  Outcast, Vol. 1: A Darkness Surrounds Him (Out...  15.44       4
# 6       6  orange: The Complete Collection 1 (orange: The...  48.41       1
# 7       7  Online Marketing for Busy Authors: A Step-By-S...  46.35       1
# 8       8                                On a Midnight Clear  14.07       3
# 9       9                                  Obsidian (Lux #1)  14.86       2
# 10     10              My Paris Kitchen: Recipes and Stories  33.37       2
# 11     11                                  Masks and Shadows  56.40       2
# 12     12  Mama Tried: Traditional Italian Cooking for th...  14.02       4
# 13     13  Lumberjanes, Vol. 2: Friendship to the Max (Lu...  46.91       2
# 14     14  Lumberjanes, Vol. 1: Beware the Kitten Holy (L...  45.61       3
# 15     15  Lumberjanes Vol. 3: A Terrible Plan (Lumberjan...  19.92       2
# 16     16  Layered: Baking, Building, and Styling Spectac...  40.11       1
# 17     17  Judo: Seven Steps to Black Belt (an Introducto...  53.90       2
# 18     18                                               Join  35.67       5
# 19     19          In the Country We Love: My Family Divided  22.00       4
#
#      Instock                                               Link
# 0   In stock  princess-jellyfish-2-in-1-omnibus-vol-01-princ...
# 1   In stock  princess-between-worlds-wide-awake-princess-5_...
# 2   In stock           pop-gun-war-volume-1-gift_918/index.html
# 3   In stock  political-suicide-missteps-peccadilloes-bad-ca...
# 4   In stock                            patience_916/index.html
# 5   In stock  outcast-vol-1-a-darkness-surrounds-him-outcast...
# 6   In stock  orange-the-complete-collection-1-orange-the-co...
# 7   In stock  online-marketing-for-busy-authors-a-step-by-st...
# 8   In stock                 on-a-midnight-clear_912/index.html
# 9   In stock                      obsidian-lux-1_911/index.html
# 10  In stock  my-paris-kitchen-recipes-and-stories_910/index...
# 11  In stock                   masks-and-shadows_909/index.html
# 12  In stock  mama-tried-traditional-italian-cooking-for-the...
# 13  In stock  lumberjanes-vol-2-friendship-to-the-max-lumber...
# 14  In stock  lumberjanes-vol-1-beware-the-kitten-holy-lumbe...
# 15  In stock  lumberjanes-vol-3-a-terrible-plan-lumberjanes-...
# 16  In stock  layered-baking-building-and-styling-spectacula...
# 17  In stock  judo-seven-steps-to-black-belt-an-introductory...
# 18  In stock                                join_902/index.html
# 19  In stock  in-the-country-we-love-my-family-divided_901/i...
#     index                                               Name  Price  Rating  \
# 0       0  Immunity: How Elie Metchnikoff Changed the Cou...  57.36       5
# 1       1  I Hate Fairyland, Vol. 1: Madly Ever After (I ...  29.17       2
# 2       2                       I am a Hero Omnibus Volume 1  54.63       3
# 3       3  How to Be Miserable: 40 Strategies You Already...  46.03       1
# 4       4      Her Backup Boyfriend (The Sorensen Family #1)  33.97       1
# 5       5               Giant Days, Vol. 2 (Giant Days #5-8)  22.11       2
# 6       6  Forever and Forever: The Courtship of Henry Lo...  29.69       3
# 7       7                 First and First (Five Boroughs #3)  15.97       4
# 8       8              Fifty Shades Darker (Fifty Shades #2)  21.96       1
# 9       9  Everydata: The Misinformation Hidden in the Li...  54.35       2
# 10     10  Don't Be a Jerk: And Other Practical Advice fr...  37.97       2
# 11     11                               Danganronpa Volume 1  51.99       4
# 12     12             Crown of Midnight (Throne of Glass #2)  43.29       3
# 13     13  Codename Baboushka, Volume 1: The Conclave of ...  36.72       4
# 14     14                                      Camp Midnight  17.08       4
# 15     15  Call the Nurse: True Stories of a Country Nurs...  29.14       5
# 16     16                                            Burning  28.81       3
# 17     17                                         Bossypants  49.46       2
# 18     18  Bitch Planet, Vol. 1: Extraordinary Machine (B...  37.92       2
# 19     19  Avatar: The Last Airbender: Smoke and Shadow, ...  28.09       2
#
#      Instock                                               Link
# 0   In stock  immunity-how-elie-metchnikoff-changed-the-cour...
# 1   In stock  i-hate-fairyland-vol-1-madly-ever-after-i-hate...
# 2   In stock        i-am-a-hero-omnibus-volume-1_898/index.html
# 3   In stock  how-to-be-miserable-40-strategies-you-already-...
# 4   In stock  her-backup-boyfriend-the-sorensen-family-1_896...
# 5   In stock     giant-days-vol-2-giant-days-5-8_895/index.html
# 6   In stock  forever-and-forever-the-courtship-of-henry-lon...
# 7   In stock     first-and-first-five-boroughs-3_893/index.html
# 8   In stock  fifty-shades-darker-fifty-shades-2_892/index.html
# 9   In stock  everydata-the-misinformation-hidden-in-the-lit...
# 10  In stock  dont-be-a-jerk-and-other-practical-advice-from...
# 11  In stock                danganronpa-volume-1_889/index.html
# 12  In stock  crown-of-midnight-throne-of-glass-2_888/index....
# 13  In stock  codename-baboushka-volume-1-the-conclave-of-de...
# 14  In stock                       camp-midnight_886/index.html
# 15  In stock  call-the-nurse-true-stories-of-a-country-nurse...
# 16  In stock                             burning_884/index.html
# 17  In stock                          bossypants_883/index.html
# 18  In stock  bitch-planet-vol-1-extraordinary-machine-bitch...
# 19  In stock  avatar-the-last-airbender-smoke-and-shadow-par...
#     index                                               Name  Price  Rating  \
# 0       0  Algorithms to Live By: The Computer Science of...  30.81       1
# 1       1       A World of Flavor: Your Gluten Free Passport  42.95       1
# 2       2  A Piece of Sky, a Grain of Rice: A Memoir in F...  56.76       5
# 3       3                                   A Murder in Time  16.64       1
# 4       4            A Flight of Arrows (The Pathfinders #2)  55.53       5
# 5       5                         A Fierce and Subtle Poison  28.13       4
# 6       6  A Court of Thorns and Roses (A Court of Thorns...  52.37       1
# 7       7  (Un)Qualified: How God Uses Broken People to D...  54.00       5
# 8       8  You Are What You Love: The Spiritual Power of ...  21.87       4
# 9       9  William Shakespeare's Star Wars: Verily, A New...  43.30       4
# 10     10                             Tuesday Nights in 1980  21.04       2
# 11     11                         Tracing Numbers on a Train  41.60       3
# 12     12               Throne of Glass (Throne of Glass #1)  35.07       3
# 13     13  Thomas Jefferson and the Tripoli Pirates: The ...  59.64       1
# 14     14                               Thirteen Reasons Why  52.72       1
# 15     15  The White Cat and the Monk: A Retelling of the...  58.08       4
# 16     16                                  The Wedding Dress  24.12       1
# 17     17                                    The Vacationers  42.15       4
# 18     18  The Third Wave: An Entrepreneurâs Vision of ...  12.61       5
# 19     19                                       The Stranger  17.44       4
#
#      Instock                                               Link
# 0   In stock  algorithms-to-live-by-the-computer-science-of-...
# 1   In stock  a-world-of-flavor-your-gluten-free-passport_87...
# 2   In stock  a-piece-of-sky-a-grain-of-rice-a-memoir-in-fou...
# 3   In stock                    a-murder-in-time_877/index.html
# 4   In stock  a-flight-of-arrows-the-pathfinders-2_876/index...
# 5   In stock          a-fierce-and-subtle-poison_875/index.html
# 6   In stock  a-court-of-thorns-and-roses-a-court-of-thorns-...
# 7   In stock  unqualified-how-god-uses-broken-people-to-do-b...
# 8   In stock  you-are-what-you-love-the-spiritual-power-of-h...
# 9   In stock  william-shakespeares-star-wars-verily-a-new-ho...
# 10  In stock              tuesday-nights-in-1980_870/index.html
# 11  In stock          tracing-numbers-on-a-train_869/index.html
# 12  In stock   throne-of-glass-throne-of-glass-1_868/index.html
# 13  In stock  thomas-jefferson-and-the-tripoli-pirates-the-f...
# 14  In stock                thirteen-reasons-why_866/index.html
# 15  In stock  the-white-cat-and-the-monk-a-retelling-of-the-...
# 16  In stock                   the-wedding-dress_864/index.html
# 17  In stock                     the-vacationers_863/index.html
# 18  In stock  the-third-wave-an-entrepreneurs-vision-of-the-...
# 19  In stock                        the-stranger_861/index.html
# Plus de page

# %% [markdown]
# ###
